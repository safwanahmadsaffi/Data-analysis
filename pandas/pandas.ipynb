# %% [markdown]
# PANDAS - (Pannel Data Analysis)
# -
# It is the Library of "PYTHON" Data Analysis USED when Data Manipulation., Cleaning work on data.
#
# DATA Manipulation
#
# Process of changing data to make it more organised and readable.
#
# Pandas has two data struture
#
# 1-Series
#
# 2-DataFrame (Tbales)

# %% [markdown]
# Creating Series
# Pnada series is a one-dimensional labeled array capabel of hloding nay data type. However, a series is a sequence of homogeneous data types, similar to an array, or column in a table.

# %%
import pandas as pd
#import seaborn as sns

# %%
#creating a series with arbitarary lsit
s=pd.Series([123,456,'FRANCE',25,"WEATHER"])
s
# Out:
# 0        123
# 1        456
# 2     FRANCE
# 3         25
# 4    WEATHER
# dtype: object

# %% [markdown]
# Creating Our First Pandas DataFrame
# -

# %%
df = pd.DataFrame()

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A1','A2','A3'])

# %%
df1.shape
# Out:
# (3, 3)

# %%
df1
# Out:
#    A1  A2  A3
# 0   1   2   3
# 1   4   5   6
# 2   7   8   9

# %%
df1.describe()
# Out:
#         A1   A2   A3
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df1.head(2)  # will print only two rows from header
# Out:
#    A1  A2  A3
# 0   1   2   3
# 1   4   5   6

# %%
df1.tail(2)
# Out:
#    A1  A2  A3
# 1   4   5   6
# 2   7   8   9

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# A1    int64
# A2    int64
# A3    int64
# dtype: object

# %%
df1.dtypes=="object"
# Out:
# A1    False
# A2    False
# A3    False
# dtype: bool

# %%
df1.dtypes[df1.dtypes=="object"]
# Out:
# Series([], dtype: object)

# %%
df1.columns
# Out:
# Index(['A1', 'A2', 'A3'], dtype='object')

# %%
df1[2:3]
# Out:
#    A1  A2  A3
# 2   7   8   9

# %%
df1.A2
# Out:
# 0    2
# 1    5
# 2    8
# Name: A2, dtype: int64

# %% [markdown]
# Reading a CVS file in python
# -

# %% [markdown]
# Creating an Excel File

# %%
ship = sns.load_dataset("titanic")
ship
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
ship.to_excel("./ship.xlsx")

# %% [markdown]
# Creaitng a CSV File

# %%
ship.to_csv("./ship.csv")

# %% [markdown]
# Reading a CSV File

# %%
df = pd.read_csv("ship.csv")

# %%
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
print(df['survived'])
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %% [markdown]
# Reading an Excel File

# %%
pd.read_excel("ship.xlsx")
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %% [markdown]
# Write a CSV File
# -

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A1','A2','A3'])

# %%
df.to_csv("export.csv")

# %%
pd.read_csv("export.csv")
# Out:
#    Unnamed: 0  A1  A2  A3
# 0           0   1   2   3
# 1           1   4   5   6
# 2           2   7   8   9

# %% [markdown]
# DataFrame Merging
# -

# %%
d1 = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A1','A2','A3'])
d1
# Out:
#    A1  A2  A3
# 0   1   2   3
# 1   4   5   6
# 2   7   8   9

# %%
d2 = pd.DataFrame([[11,22,33],[44,55,66],[77,88,99]],columns=['X','Y','Z'])
d2
# Out:
#     X   Y   Z
# 0  11  22  33
# 1  44  55  66
# 2  77  88  99
